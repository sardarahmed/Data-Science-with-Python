# %% [markdown]
# # Intro to MatPlotLib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
weather_data =pd.DataFrame( {
    'months': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
    'temp': [5, 10, 20, 25, 28, 30, 35, 40, 38, 30, 25, 15],
})
weather_data.head()
# Out:
#   months  temp
# 0    Jan     5
# 1    Feb    10
# 2    Mar    20
# 3    Apr    25
# 4    May    28

# %%
fig, ax = plt.subplots()
ax.plot(weather_data['months'], weather_data['temp'])
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(weather_data['months'], weather_data['temp'], marker='o', color='r', linestyle='--')
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(weather_data['months'], weather_data['temp'], marker='o', color='r', linestyle='--')
ax.set_xlabel('Month')
ax.set_ylabel('Temperature')
ax.set_title('Weather Data')
plt.show()

# %%
weather_data.plot(x='months', y='temp', kind='bar')
plt.show()

# %%
abbottabad_data =pd.DataFrame( {
    'months': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
    'temp': [5, 10, 20, 23, 26, 28, 35, 38, 35, 30, 25, 18]
})

# %%
fig, ax = plt.subplots(2,1, sharey=True)
ax[0].plot(weather_data['months'], weather_data['temp'], marker='o',  color='r', linestyle='--')
ax[0].set_xlabel('Month')
ax[0].set_ylabel('Temperature')
ax[0].set_title('Weather Data')
ax[1].plot(abbottabad_data['months'], abbottabad_data['temp'], marker='v', color='b', linestyle='-')
ax[1].set_xlabel('Month')
ax[1].set_ylabel('Temperatur')
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(weather_data.index, weather_data['temp'], marker='o', color='r', linestyle='--')
ax.set_xlabel('Month')
ax.set_ylabel('Temperature')
ax.set_title('Weather Data')
plt.show()

# %%
weather = pd.DataFrame({
    'date': ['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04', '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08', '2019-01-09', '2019-01-10', '2019-01-11', '2019-01-12'],
    'temp': [5, 10, 20, 25, 28, 30, 35, 40, 38, 30, 25, 15],
    'co2': [400, 410, 420, 430, 440, 450, 460, 470, 480, 490, 500, 510], })
weather.head()
# Out:
#          date  temp  co2
# 0  2019-01-01     5  400
# 1  2019-01-02    10  410
# 2  2019-01-03    20  420
# 3  2019-01-04    25  430
# 4  2019-01-05    28  440

# %%
weather.set_index('date')
# Out:
#             temp  co2
# date
# 2019-01-01     5  400
# 2019-01-02    10  410
# 2019-01-03    20  420
# 2019-01-04    25  430
# 2019-01-05    28  440
# 2019-01-06    30  450
# 2019-01-07    35  460
# 2019-01-08    40  470
# 2019-01-09    38  480
# 2019-01-10    30  490
# 2019-01-11    25  500
# 2019-01-12    15  510

# %%
fig, ax = plt.subplots()
ax.plot(weather.index, weather['co2'])
ax.plot(weather.index, weather['temp'])
ax.set_xlabel('Time')
ax.set_ylabel('CO2/Temperature')
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(weather.index, weather['co2'], color='blue')
ax.set_xlabel('Time')
ax.set_ylabel('CO2', color='blue')
ax2 = ax.twinx()
ax2.plot(weather.index, weather['temp'], color='red')
ax2.set_ylabel('Temperature', color='red')
plt.show()
